# %%
import pandas as pd
import numpy as np

# %%
avocado=pd.read_csv("avocado.csv",parse_dates=['Date'],index_col="Date")
# type(avocado)
# avocado.shape
avocado
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
# ...                ...           ...           ...      ...        ...
# 2018-02-04           7          1.63      17074.83  2046.96    1529.20
# 2018-01-28           8          1.71      13888.04  1191.70    3431.50
# 2018-01-21           9          1.87      13766.76  1191.92    2452.79
# 2018-01-14          10          1.93      16205.22  1527.63    2981.04
# 2018-01-07          11          1.62      17489.58  2894.77    2356.13
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# ...

# %%
avocado.drop(avocado.columns[avocado.columns.str.contains('unnamed', case=False)],
       axis=1, inplace=True)
# avocado.head()

# %%
avocado.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
avocado.region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
avocado.type.unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
avocado = avocado.rename(columns={'AveragePrice':'Average Price','4046': 'PLU 4046', '4225': 'PLU 4225','4770':'PLU 4770'})
avocado.head()
# Out:
#             Average Price  Total Volume  PLU 4046   PLU 4225  PLU 4770  \
# Date
# 2015-12-27           1.33      64236.62   1036.74   54454.85     48.16
# 2015-12-20           1.35      54876.98    674.28   44638.81     58.33
# 2015-12-13           0.93     118220.22    794.70  109149.67    130.50
# 2015-12-06           1.08      78992.15   1132.00   71976.41     72.58
# 2015-11-29           1.28      51039.60    941.48   43838.39     75.78
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-12-27     8696.87     8603.62       93.25          0.0  conventional
# 2015-12-20     9505.56     9408.07       97.49          0.0  conventional
# 2015-12-13     8145.35     8042.21      103.14          0.0  conventional
# 2015-12-06     5811.16     5677.40      133.76          0.0  conventional
# 2015-11-29     6183.95     5986.26      197.69          0.0  conventional
#
#             year  region
# Date
# 2015-12-27  2015  Albany
# ...

# %%
avocado.index
# Out:
# DatetimeIndex(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06',
#                '2015-11-29', '2015-11-22', '2015-11-15', '2015-11-08',
#                '2015-11-01', '2015-10-25',
#                ...
#                '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18',
#                '2018-02-11', '2018-02-04', '2018-01-28', '2018-01-21',
#                '2018-01-14', '2018-01-07'],
#               dtype='datetime64[ns]', name='Date', length=18249, freq=None)

# %%
avocado["2018-03-11"]
# Out:
#             Average Price  Total Volume   PLU 4046   PLU 4225  PLU 4770  \
# Date
# 2018-03-11           1.12     144648.75   15823.35  110950.68     70.00
# 2018-03-11           0.96     695821.13  320199.40   36356.76   1628.73
# 2018-03-11           1.36     874780.27  104341.22  484252.62   4933.91
# 2018-03-11           1.26      80611.01   28399.47    2279.82  12280.50
# 2018-03-11           1.34     629090.87   23641.04  479640.60   1840.01
# ...                   ...           ...        ...        ...       ...
# 2018-03-11           1.25       4685.01     168.95      61.01      0.00
# 2018-03-11           1.31       8115.07     101.14     392.38      0.00
# 2018-03-11           1.52    1664234.88  129169.72  408763.50   1401.87
# 2018-03-11           1.63     264691.87   27566.25   60383.57    276.42
# 2018-03-11           1.56      22128.42    2162.67    3194.25      8.93
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# ...

# %%
import seaborn as sns
g=sns.pairplot(avocado)
# Out:
# Error in callback <function flush_figures at 0x000002654A1B5708> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...

# %%
 import matplotlib.pyplot as plt
# plt.figure(figsize=(15,8))
# #avocado_month.plot(kind='bar', legend=True, fontsize=12, color ='lightseagreen',rot=45)
# plt.title('Avacodo Sales by Month', size=22)
# plt.xlabel('Month',size=20)
# plt.ylabel('Sales',size=20)
# plt.legend(loc=2)
# plt.show()

# %%
ax = sns.stripplot(x="type", y="Large Bags", data=avocado)

# %%
# plt.figure(figsize=(15,8))
from matplotlib import rcParams
rcParams['figure.figsize']=15,8
avocado.plot(kind='scatter',x='Average Price', y='Large Bags')

# %%
from sklearn.linear_model import LinearRegression
#LinReg=LinearRegression()
#LinReg(avocado.Average Price,avocado.Large Bags)

# %%
import seaborn as sns
plt.figure(figsize=(15,8))
corrmat = avocado.corr()
# sns.set(rc={'figure.figsize':(12.7,8.27)})

ax = sns.heatmap(corrmat, cmap ="YlGnBu", vmin=-1, vmax=1, center= 0,linewidths = 0.1,annot=True,square=True)

ax.set_ylim(10.0, 0)
# Out:
# (10.0, 0)

# %%
plt.figure(figsize=(15,8))

matrix = np.triu(corrmat)
sns.heatmap(corrmat, annot=True, mask=matrix)
#ax.get_ylim()
#(5.5, 0.5)
ax.set_ylim(11, 0)
# Out:
# (11, 0)

# %%
matrix = np.tril(corrmat)
sns.heatmap(corrmat, annot=True, mask=matrix)
ax.get_ylim()
(5.5, 0.5)
ax.set_ylim(4, 0)
# Out:
# (4, 0)

# %%
plt.scatter(avocado['Large Bags'],avocado['Total Bags'])
plt.title('Avacodo Sales by Month', size=22)
plt.xlabel('Large Bags',size=20)
plt.ylabel('Total Bags',size=20)
plt.legend(loc=2)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(avocado['Small Bags'],avocado['Total Bags'])

# %%
plt.scatter(avocado['XLarge Bags'],avocado['Total Bags'])

# %%
avocado_Atlanta=avocado.loc[avocado['region'].isin(['Atlanta'])]
avocado_Atlanta=avocado_Atlanta.resample('M').mean()
avocado_Atlanta.reset_index().plot(x='Date', y='Large Bags',kind='line',color='rosybrown')

# %%
# Group By
byCity = avocado.groupby('region')
byCity

# Loop through the output + resample & mean + plot graphs
for region, region_avocado in byCity:
    print(region)
    print(region_avocado)
    region_sampled_table=region_avocado.resample('M').mean()
    print(region)
    region_sampled_table.reset_index().plot(x='Date', y='Large Bags')
# Out:
# Albany
#             Average Price  Total Volume  PLU 4046   PLU 4225  PLU 4770  \
# Date
# 2015-12-27           1.33      64236.62   1036.74   54454.85     48.16
# 2015-12-20           1.35      54876.98    674.28   44638.81     58.33
# 2015-12-13           0.93     118220.22    794.70  109149.67    130.50
# 2015-12-06           1.08      78992.15   1132.00   71976.41     72.58
# 2015-11-29           1.28      51039.60    941.48   43838.39     75.78
# ...                   ...           ...       ...        ...       ...
# 2018-02-04           1.52       4124.96    118.38     420.36      0.00
# 2018-01-28           1.32       6987.56    433.66     374.96      0.00
# 2018-01-21           1.54       3346.54     14.67     253.01      0.00
# 2018-01-14           1.47       4140.95      7.30     301.87      0.00
# 2018-01-07           1.54       4816.90     43.51     412.17      0.00
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# ...

# %%
import matplotlib.pylab as pylab
# %matplotlib inline

# %%
# Group By
byType = avocado.groupby('type').plot(kind='bar')
# byType
# Loop through the output + resample & mean + plot graphs
# for Type, type_avocado in byType:
#     print(Type)
#     print(type_avocado)
#     Type_sampled_table=type_avocado.resample('M').mean()
#     print(region)

# %%
Type_sampled_table.reset_index().plot(x='Date', y='Total Bags')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9312721b6471> in <module>
# ----> 1 Type_sampled_table.reset_index().plot(x='Date', y='Total Bags')
#
# NameError: name 'Type_sampled_table' is not defined

# %%
X=avocado_Atlanta[['Large Bags','Small Bags','XLarge Bags']]
y=avocado_Atlanta['Total Bags']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
len(X_train)

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(X_train,y_train)

# %%
clf.predict(X_test)

# %%
clf.score(X_test,y_test)

# %%
region_sampled_table.reset_index().plot(x='Date', y='Total Bags')

# %%
X=Type_sampled_table[['Large Bags','Small Bags','XLarge Bags']]
y=Type_sampled_table['Total Bags']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
len(X_train)

# %%
clf_type=LinearRegression()
clf_type.fit(X_train,y_train)

# %%
clf_type.predict(X_test)

# %%
clf_type.score(X_test,y_test)

# %%
avocado_series = pd.Series(avocado['Total Bags'].values, index=avocado['Date'])
